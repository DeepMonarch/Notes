# %% [markdown]
# ### Custom-Hand Crafted Features

# %% [markdown]
# Using domain knowledge to make features such as in sentiment analysis it could be number of positive reviews,
# number of negetive reviews etc.
