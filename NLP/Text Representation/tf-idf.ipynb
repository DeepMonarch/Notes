# %% [markdown]
# ### TF-IDF

# %%
# TF - Term Frequency, IDF - Inverse Document Frequency
# TF(t,d) = (Number of times term t appears in a document) / (Total number of terms in the document)
# IDF(t) = log_e(Total number of documents / Number of documents with term t in it)
# TF-IDF(t,d) = TF(t,d) * IDF(t)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'text': ['I love NLP', 'NLP is great', 'I enjoy learning NLP'],
    'output': [1, 1, 1]
})

df
# Out:
#                    text  output
# 0            I love NLP       1
# 1          NLP is great       1
# 2  I enjoy learning NLP       1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
tfidf.fit_transform(df.get('text')).toarray()
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.861037  ,
#         0.50854232],
#        [0.        , 0.65249088, 0.65249088, 0.        , 0.        ,
#         0.38537163],
#        [0.65249088, 0.        , 0.        , 0.65249088, 0.        ,
#         0.38537163]])

# %%
print(tfidf.idf_)
print(tfidf.get_feature_names_out())
# Out:
# [1.69314718 1.69314718 1.69314718 1.69314718 1.69314718 1.        ]
# ['enjoy' 'great' 'is' 'learning' 'love' 'nlp']
