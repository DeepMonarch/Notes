# %% [markdown]
# ### Handling Emojis:

# %% [markdown]
# #### Option 1: Remove Emojis

# %%
import re 
def remove_emojis(text):
    """Remove emojis from the text"""
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
remove_emojis("Hello 😊! This is a test message with emojis 🚀.")
# Out:
# 'Hello ! This is a test message with emojis .'

# %% [markdown]
# #### Option 2: Replace them with their meaning

# %%
import emoji
print(emoji.demojize("Hello 😊! This is a test message with emojis 🚀.  "))
# Out:
# Hello :smiling_face_with_smiling_eyes:! This is a test message with emojis :rocket:.
