# %% [markdown]
# ### Using Regular Expression:

# %% [markdown]
# #### better than using split function

# %%
import re
sent3 = 'I am going to delhi! I will meet my friends there.'
tokens = re.findall("[\w']+", sent3)
tokens
# Out:
# ['I',
#  'am',
#  'going',
#  'to',
#  'delhi',
#  'I',
#  'will',
#  'meet',
#  'my',
#  'friends',
#  'there']
