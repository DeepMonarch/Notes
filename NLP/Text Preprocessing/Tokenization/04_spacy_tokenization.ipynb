# %% [markdown]
# ### Using SpaCy Library:

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
#python -m spacy download en_core_web_sm
sent1 = 'I am going to delhi!' 
doc1 = nlp(sent1)
for token in doc1:
    print(token.text)
