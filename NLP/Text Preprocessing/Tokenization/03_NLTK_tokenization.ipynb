# %% [markdown]
# ### NLTK (Library):

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\ALL IS
# [nltk_data]     WELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\ALL IS
# [nltk_data]     WELL\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

sent1 = 'I am going to delhi!'
print(word_tokenize(sent1))

sent2 = 'Hello world. This is a test.'
print(sent_tokenize(sent2))
# Out:
# ['I', 'am', 'going', 'to', 'delhi', '!']
# ['Hello world.', 'This is a test.']
