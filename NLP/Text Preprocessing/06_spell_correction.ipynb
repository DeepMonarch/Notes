# %% [markdown]
# ### Spelling Correction:

# %%
from textblob import TextBlob

incorrect_text = "ceertain conditionas duringg the executionn"
textblb = TextBlob(incorrect_text).correct().string
print(textblb)
# Out:
# certain conditions during the execution
